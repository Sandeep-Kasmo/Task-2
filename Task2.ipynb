# %%
import pandas as pd
import re

# %%
df=pd.read_csv(r"C:\Users\sande\Downloads\customer_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              950 non-null    object
#  3   phone              984 non-null    object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
df.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                50
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df['email']=df.apply(lambda row:f"{row['name'].lower().strip().replace(' ','_')}@example.com" if pd.isnull(row['email']) else row['email'],axis=1)

# %%
df.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df['email'].value_counts()
# Out:
# email
# dblanchard@example.net       3
# ipalmer@example.org          3
# qwilliams@example.com        3
# kevin69@example.net          3
# xthompson@example.net        3
#                             ..
# colleenfarley@example.org    1
# kimberly51@example.org       1
# todd12@example.org           1
# ithomas@example.net          1
# michael42@example.com        1
# Name: count, Length: 910, dtype: int64

# %%
df['phone']=df.apply(lambda row:"987-654-3210" if pd.isnull(row['phone']) else (row['phone']),axis=1)

# %%
df.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# dtype: int64

# %%
df['email_flag']=df['email'].astype(str).str.match(r'^[a-zA-Z0-9._]+@[a-z]+\.[a-z]{2,}$',na=False)

# %%
df['email_flag'].value_counts()
# Out:
# email_flag
# True    1000
# Name: count, dtype: int64

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df.drop(columns=['email_flag'],inplace=True)

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df['phone_flag']=df['phone'].astype(str).str.match(r'^\d{2,}-\d{3,}-\d{4,}$',na=False)

# %%
df['phone_flag'].value_counts()
# Out:
# phone_flag
# True    1000
# Name: count, dtype: int64

# %%
df['phone']=df.apply(lambda row:"987-654-3210" if row['phone']=='e' or row['phone']=='0' else (row['phone']),axis=1)

# %%
df[df['phone_flag']==False]['phone']
# Out:
# 289    309-515-738521
# Name: phone, dtype: object

# %%
df['phone_flag'].value_counts()
# Out:
# phone_flag
# True    1000
# Name: count, dtype: int64

# %%
df['phone']=df['phone'].astype(str).str.replace(r'[()a-zA-Z]','',regex=True)

# %%
df.drop(columns=['phone_flag'],inplace=True)

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              1000 non-null   object
#  3   phone              1000 non-null   object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
df['registration_date']=pd.to_datetime(df['registration_date'],errors='coerce').dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              1000 non-null   object
#  3   phone              1000 non-null   object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
l1=df.columns

# %%
print(type(l1))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
for i in l1:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              1000 non-null   object
#  3   phone              1000 non-null   object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
df.drop_duplicates()
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
dial_code=pd.read_csv(r"C:\Users\sande\Downloads\Country_2-3_Digits_Codes.csv")

# %%
dial_code
# Out:
#                COUNTRY  A2   A3  NUM DIALINGCODE
# 0          Afghanistan  AF  AFG    4          93
# 1              Albania  AL  ALB    8         355
# 2              Algeria  DZ  DZA   12         213
# 3       American Samoa  AS  ASM   16       1-684
# 4              Andorra  AD  AND   20         376
# ..                 ...  ..  ...  ...         ...
# 243  Wallis and Futuna  WF  WLF  876         681
# 244     Western Sahara  EH  ESH  732         212
# 245              Yemen  YE  YEM  887         967
# 246             Zambia  ZM  ZMB  894         260
# 247           Zimbabwe  ZW  ZWE  716         263
#
# [248 rows x 5 columns]

# %%
dial_code.drop(columns=['COUNTRY','A3','NUM'],inplace=True)

# %%
dial_code.to_csv('dial_code.csv',index=False)

# %%
df['state_code']=df['address'].astype(str).str[-8:-6]

# %%
df['country_code']
# Out:
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US
#        ..
# 995    US
# 996    US
# 997    US
# 998    US
# 999    US
# Name: country_code, Length: 1000, dtype: object

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df['address'].to_csv('Address.csv',index=False)

# %%
df['country_code']='US'
#since all the entries present in the dataset belong to US, so we asign country code=US

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
dial_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A2           247 non-null    object
#  1   DIALINGCODE  248 non-null    object
# dtypes: object(2)
# memory usage: 4.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              1000 non-null   object
#  3   phone              1000 non-null   object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
#  7   country_code       1000 non-null   object
#  8   state_code         1000 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 70.4+ KB

# %%
code_map=dict(zip(dial_code['A2'],dial_code['DIALINGCODE']))
#create a key_value pair dictionary to map like map_dict ={ countrycode:dialing_code} so that we can map this to 
# df with df[dial_code]=df[country_code].map(map_dict)

# %%
code_map
# Out:
# {'AF': '93',
#  'AL': '355',
#  'DZ': '213',
#  'AS': '1-684',
#  'AD': '376',
#  'AO': '244',
#  'AI': '1-264',
#  'AQ': '672',
#  'AG': '1-268',
#  'AR': '54',
#  'AM': '374',
#  'AW': '297',
#  'AU': '61',
#  'AT': '43',
#  'AZ': '994',
#  'BS': '1-242',
#  'BH': '973',
#  'BD': '880',
#  'BB': '1-246',
#  'BY': '375',
#  'BE': '32',
#  'BZ': '501',
#  'BJ': '229',
#  'BM': '1-441',
#  'BT': '975',
#  'BO': '591',
#  'BQ': '599',
#  'BA': '387',
#  'BW': '267',
#  'BV': '47',
#  'BR': '55',
#  'IO': '246',
#  'BN': '673',
#  'BG': '359',
#  'BF': '226',
#  'BI': '257',
#  'KH': '855',
#  'CM': '237',
#  'CA': '1',
#  'CV': '238',
#  'KY': '1-345',
#  'CF': '236',
#  'TD': '235',
#  'CL': '56',
#  'CN': '86',
#  'CX': '61',
#  'CC': '61',
#  'CO': '57',
#  'KM': '269',
#  'CG': '242',
#  'CD': '243',
#  'CK': '682',
#  'CR': '506',
#  'HR': '385',
#  'CU': '53',
#  'CW': '599',
#  'CY': '357',
#  'CZ': '420',
#  'CI': '225',
#  'DK': '45',
#  'DJ': '253',
#  'DM': '1-767',
# ...

# %%
df['dialing_code']='+'+df['country_code'].map(code_map)+'-'

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df['dial_num']=df.apply(lambda row:f"{row['dialing_code']}{row['phone']}",axis=1)
# append phone number to dialcode and create a new column dial_num which is fully a number

# %%
df['dial_num']
# Out:
# 0      +1-619-723-4258
# 1      +1-537-674-1158
# 2      +1-810-256-4505
# 3      +1-423-222-9779
# 4      +1-220-763-3522
#             ...
# 995    +1-638-989-9441
# 996    +1-483-625-2940
# 997    +1-390-747-3088
# 998    +1-257-409-8196
# 999    +1-692-333-6880
# Name: dial_num, Length: 1000, dtype: object

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df.drop(columns=['phone','state_code','dialing_code','country_code'],inplace=True)
#so, drop the unnececsary columns

# %%
df
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#                                                address registration_date  \
# 0                          USNS Santiago, FPO AE 80872        2025-01-25
# ...

# %%
# finally export the cleaned dataset
df.to_csv('Final_customer_list_cleaned_mapped.csv',index=False)
